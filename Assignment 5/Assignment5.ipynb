# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet as wn

# %%
def get_wordnet_relations(word):
    results = {
        "synonyms": set(),
        "antonyms": set(),
        "hypernyms": set(),
        "hyponyms": set()
    }

    for synset in wn.synsets(word):
        # Synonyms
        for lemma in synset.lemmas():
            results["synonyms"].add(lemma.name())

            # Antonyms
            if lemma.antonyms():
                results["antonyms"].add(lemma.antonyms()[0].name())

        # Hypernyms
        for hypernym in synset.hypernyms():
            for lemma in hypernym.lemmas():
                results["hypernyms"].add(lemma.name())

        # Hyponyms
        for hyponym in synset.hyponyms():
            for lemma in hyponym.lemmas():
                results["hyponyms"].add(lemma.name())

    return results

# %%
word = "happy"
relations = get_wordnet_relations(word)

print("Word:", word)
print("Synonyms:", relations["synonyms"])
print("Antonyms:", relations["antonyms"])
print("Hypernyms:", relations["hypernyms"])
print("Hyponyms:", relations["hyponyms"])
# Out:
# Word: happy
# Synonyms: {'well-chosen', 'glad', 'felicitous', 'happy'}
# Antonyms: {'unhappy'}
# Hypernyms: set()
# Hyponyms: set()

# %%
def analyze_text(text):
    words = set(text.lower().split())
    analysis = {}

    for word in words:
        analysis[word] = get_wordnet_relations(word)

    return analysis

# %%
text = "The happy child felt joyful but not sad."
results = analyze_text(text)

for word, relations in results.items():
    print(f"\n🔹 Word: {word}")
    print("  Synonyms:", relations["synonyms"])
    print("  Antonyms:", relations["antonyms"])
    print("  Hypernyms:", relations["hypernyms"])
    print("  Hyponyms:", relations["hyponyms"])
# Out:
# 🔹 Word: sad.
#   Synonyms: set()
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: not
#   Synonyms: {'non', 'not'}
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: felt
#   Synonyms: {'palpate', 'finger', 'felt_up', 'felt', 'matte', 'matte_up', 'experience', 'find', 'matt-up', 'feel', 'mat', 'sense', 'mat_up'}
#   Antonyms: set()
#   Hypernyms: {'look', 'find', 'consider', 'seek', 'regain', 'snarl', 'appear', 'touch', 'think', 'textile', 'be', 'perceive', 'go_through', 'fabric', 'look_for', 'comprehend', 'material', 'change', 'experience', 'cloth', 'conclude', 'believe', 'reason', 'cover', 'reason_out', 'entangle', 'conceive', 'see', 'seem', 'tangle', 'search', 'mat'}
#   Hyponyms: {'incline', 'scrabble', 'sympathize', 'entertain', 'smoulder', 'congratulate', 'anger', 'die', 'plume', 'rejoice', 'hold', 'nurse', 'regret', 'shine', 'suffocate', 'pride_oneself', 'recapture', 'sympathise', 'fume', 'feel_like_a_million', 'repent', 'grope_for', 'suffer', 'cool_off', 'glow', 'radiate', 'pride', 'harbor', 'burn', 'chafe', 'fly_high', 'joy', 'beam', 'rue', 'harbour', 'crawl', 'take_pride', 'sadden', 'smolder', 'see_red', 'feel_like_a_million_dollars'}
#
# 🔹 Word: but
#   Synonyms: {'merely', 'only', 'but', 'simply', 'just'}
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: happy
#   Synonyms: {'well-chosen', 'glad', 'felicitous', 'happy'}
#   Antonyms: {'unhappy'}
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: joyful
#   Synonyms: {'elated', 'gleeful', 'joyful', 'jubilant'}
#   Antonyms: {'sorrowful'}
#   Hypernyms: set()
#   Hyponyms: set()
#
# 🔹 Word: child
#   Synonyms: {'minor', 'nestling', 'fry', 'baby', 'shaver', 'nipper', 'tiddler', 'youngster', 'kid', 'small_fry', 'tike', 'tyke', 'child'}
#   Antonyms: {'parent'}
#   Hypernyms: {'offspring', 'descendent', 'somebody', 'soul', 'juvenile_person', 'someone', 'mortal', 'progeny', 'person', 'descendant', 'individual', 'juvenile', 'issue'}
#   Hyponyms: {'toddler', 'sprog', 'poster_child', 'urchin', 'male_offspring', 'changeling', 'preschooler', 'rascal', 'waif', 'bairn', 'foster-child', 'man-child', 'army_brat', 'street_child', 'silly', 'buster', 'infant_prodigy', 'scamp', 'tot', 'child_prodigy', 'yearling', 'baby', 'imp', 'kindergartener', 'foster_child', 'fosterling', 'kindergartner', 'orphan', 'female_offspring', 'scallywag', 'picaninny', 'infant', 'peanut', 'wonder_child', 'stepchild', 'bambino', 'piccaninny', 'kiddy', 'monkey', 'babe', 'scalawag', 'pickaninny', 'rapscallion'}
#
# 🔹 Word: the
#   Synonyms: set()
#   Antonyms: set()
#   Hypernyms: set()
#   Hyponyms: set()
